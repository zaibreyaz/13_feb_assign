# %%
"""Q1. Explain why we have to use the Exception class while creating a Custom Exception.

    Ans: When creating a custom exception in a programming language like Python, it is essential to inherit from a base class for all exceptions, 
        which in Python is the Exception class. By inheriting from the Exception class, you can define and customize your own exception with a 
        unique error message and other properties. This also enables your custom exception to inherit all the standard methods and attributes of the Exception class, 
        which are common across all exceptions, making it easier for other developers to use and understand your code.
"""

# %%
"""Q2. Write a python program to print Python Exception Hierarchy."""

# Ans: 

import inspect

def treeClass(cls, ind = 0):
    print ('-' * ind, cls.__name__)
    for i in cls.__subclasses__():
        treeClass(i, ind + 3)
  
print("Hierarchy for Built-in exceptions is : ")
inspect.getclasstree(inspect.getmro(BaseException))
treeClass(BaseException)
# Out:
# Hierarchy for Built-in exceptions is :
#  BaseException
# --- Exception
# ------ TypeError
# --------- FloatOperation
# --------- MultipartConversionError
# ------ StopAsyncIteration
# ------ StopIteration
# ------ ImportError
# --------- ModuleNotFoundError
# --------- ZipImportError
# ------ OSError
# --------- ConnectionError
# ------------ BrokenPipeError
# ------------ ConnectionAbortedError
# ------------ ConnectionRefusedError
# ------------ ConnectionResetError
# --------------- RemoteDisconnected
# --------- BlockingIOError
# --------- ChildProcessError
# --------- FileExistsError
# --------- FileNotFoundError
# --------- IsADirectoryError
# --------- NotADirectoryError
# --------- InterruptedError
# ------------ InterruptedSystemCall
# --------- PermissionError
# --------- ProcessLookupError
# --------- TimeoutError
# --------- UnsupportedOperation
# --------- itimer_error
# --------- herror
# --------- gaierror
# --------- SSLError
# ------------ SSLCertVerificationError
# ...

# %%
"""Q3. What errors are defined in the ArithmeticError class? Explain any two with an example.

    Ans: The ArithmeticError class is a built-in Python exception class that is raised when an arithmetic operation fails. 
    This class is a subclass of the Exception class and serves as a base class for a number of other built-in exceptions that are related to arithmetic operations.
    Examples: 
    1. ZeroDivisionError: This error is raised when you try to divide a number by zero. For example, consider the following code:"""

x = 5
y = 0
z = x / y

"""
        When you try to run this code, it will raise a ZeroDivisionError because you are attempting to divide x by zero, which is not a valid operation.

    2.OverflowError: This error is raised when a calculation exceeds the maximum representable value for a numeric type. For example, consider the following code:"""

x = 2 ** 10000

"""
        In this case, the value of x is so large that it exceeds the maximum representable value for a Python integer, which will cause an OverflowError to be raised.
    
"""

# %%
"""Q4. Why LookupError class is used? Explain with an example KeyError and IndexError."""

"""Ans: The LookupError class is a built-in Python exception class that serves as a base class for several other built-in exceptions related to lookup operations. 
        These operations typically involve accessing elements in a sequence, mapping, or other data structure.
        
    Examples: 
        1. KeyError: This error is raised when you try to access a non-existent key in a dictionary. For example:
"""
my_dict = {'foo': 42, 'bar': 23}
print(my_dict['baz'])

"""

            In this case, the key 'baz' does not exist in the dictionary, so a KeyError will be raised.
        
        2. IndexError: This error is raised when you try to access an index that is outside the bounds of a sequence. For example:
"""

my_list = [1, 2, 3]
print(my_list[3])

"""
                In this case, the list my_list only contains three elements, so trying to access the fourth element with an index of 3 will cause an IndexError to be raised.
    
"""

# %%
"""Q5. Explain ImportError. What is ModuleNotFoundError?"""

"""Ans: ImportError is a built-in Python exception that is raised when a module, package, or object cannot be imported for some reason. 
        This can occur for a number of reasons, such as a missing module, a syntax error in the module, or a version mismatch between the module and the Python interpreter.

        ModuleNotFoundError is a subclass of ImportError that was added in Python 3.6 to provide more specific information about import errors. 
        It is raised when the module that is being imported cannot be found. This error is often caused by misspelling the name of the module, 
        specifying an incorrect path to the module, or by not installing the module.
        
"""

# %%
"""Q6. List down some best practices for exception handling in python.

    Ans: 1.Only catch exceptions that you can handle.
         2.Use multiple except blocks to handle different types of exceptions.
         3.Use finally blocks to clean up resources.
         4.Use custom exceptions for specific errors.
         5.Use Exception(Base) class at the end of except block.

"""
